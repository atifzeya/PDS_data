# %%
import pandas as pd
import numpy as np
from requests.utils import requote_uri
from bs4 import BeautifulSoup
import requests
from urllib import request
from datetime import date

# %%
years = [2017,2018,2019,2020]
state_name_codes = [
    {"name": "ANDAMAN & NICOBAR ISLANDS", "id": 35},
    {"name": "ANDHRA PRADESH","id":28},
    {"name": "ARUNACHAL PRADESH","id":12},
    {"name": "ASSAM","id":18},
    {"name": "BIHAR","id":10},
    {"name": "CHHATTISGARH","id":22},
    {"name": "DADRA & NAGAR HAVELI","id":26},
    {"name": "DAMAN & DIU","id":25},
    {"name": "DELHI","id":7},
    {"name": "GOA","id":30},
    {"name": "GUJARAT","id":24},
    {"name": "HARYANA","id":6},
    {"name": "HIMACHAL PRADESH","id":2},
    {"name": "JAMMU AND KASHMIR","id":1},
    {"name": "JHARKHAND","id":20},
    {"name": "KARNATAKA","id":29},
    {"name": "KERALA","id":32},
    {"name": "LADAKH","id":37},
    {"name": "LAKSHADWEEP","id":31},
    {"name": "MADHYA PRADESH","id":23},
    {"name": "MAHARASHTRA","id":27},
    {"name": "MANIPUR","id":14},
    {"name": "MEGHALAYA","id":17},
    {"name": "MIZORAM","id":15},
    {"name": "NAGALAND","id":13},
    {"name": "ODISHA","id":21},
    {"name": "PUNJAB","id":3},
    {"name": "RAJASTHAN","id":8},
    {"name": "SIKKIM","id":11},
    {"name": "TAMIL NADU","id":33},
    {"name": "TELANGANA","id":36},
    {"name": "TRIPURA","id":16},
    {"name": "UTTAR PRADESH","id":5},
    {"name": "UTTARAKHAND","id":9},
    {"name": "WEST BENGAL","id":19}    
]

# %%
total_data = []
col_names = ['dfso','total_rice_allocated','total_wheat_allocated','total_qty_allocated',
                      'total_rice_distributed_unautomated','total_wheat_distributed_unautomated','total_qty_distributed_unautomated',
                      'percent_qty_distributed_unautomated','total_rice_distributed_automated','total_wheat_distributed_automated',
                      'total_qty_distributed_automated','percentage_qty_distributed_automated','total_qty_allocated_automated']
for year in years:
    for month in list(range(1,13)):
        for state in state_name_codes:
            print(year,month)
            print(state)
            # https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=1&y=2020&s=12&sn=ARUNACHAL%20PRADESH
            url = requote_uri(f"https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m={month}&y={year}&s={str(state['id']).zfill(2)}&sn={state['name']}")
            print(url)
            html_content = requests.get(url).content
            soup = BeautifulSoup(html_content, 'html.parser')
            
            try:
                table_str = str(soup.select('table[id="example"]')[0])
                # print(table_str)
                df = pd.read_html(table_str)[0]
                df.columns = range(df.shape[1])
                df = df.replace("-", 0)
                df.drop(0, axis=1, inplace = True)
#                 display(df)
                df.columns = col_names
                df = df.head(-1)
                df.insert(0, 'state_name', state['name'])
                df.insert(0, 'state_code', state['id'])
                df.insert(0, 'month_year',  date(year,month,1).strftime("%b-%Y"))
                
                num_cols = col_names[1:]
                df[num_cols] = pd.to_numeric(df[num_cols].stack()).unstack()
                df['total_rice_distributed'] = df['total_rice_distributed_unautomated'] + df['total_rice_distributed_automated'] 
                df['total_wheat_distributed'] = df['total_wheat_distributed_unautomated'] + df['total_wheat_distributed_automated'] 
#                 display(df)
#                 print(df.dtypes)
                total_data.append(df)
            except IndexError:
                pass
# Out:
# 2017 1
# {'name': 'ANDAMAN & NICOBAR ISLANDS', 'id': 35}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=1&y=2017&s=35&sn=ANDAMAN%20&%20NICOBAR%20ISLANDS
# 2017
# {'name': 'ANDAMAN & NICOBAR ISLANDS', 'id': 35}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=35&sn=ANDAMAN%20&%20NICOBAR%20ISLANDS
# 2020 11
# {'name': 'ANDHRA PRADESH', 'id': 28}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=28&sn=ANDHRA%20PRADESH
# 2020 11
# {'name': 'ARUNACHAL PRADESH', 'id': 12}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=12&sn=ARUNACHAL%20PRADESH
# 2020 11
# {'name': 'ASSAM', 'id': 18}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=18&sn=ASSAM
# 2020 11
# {'name': 'BIHAR', 'id': 10}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=10&sn=BIHAR
# 2020 11
# {'name': 'CHHATTISGARH', 'id': 22}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=22&sn=CHHATTISGARH
# 2020 11
# {'name': 'DADRA & NAGAR HAVELI', 'id': 26}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=26&sn=DADRA%20&%20NAGAR%20HAVELI
# 2020 11
# {'name': 'DAMAN & DIU', 'id': 25}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=25&sn=DAMAN%20&%20DIU
# 2020 11
# {'name': 'DELHI', 'id': 7}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=07&sn=DELHI
# 2020 11
# {'name': 'GOA', 'id': 30}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=30&sn=GOA
# 2020 11
# {'name': 'GUJARAT', 'id': 24}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=24&sn=GUJARAT
# 2020 11
# {'name': 'HARYANA', 'id': 6}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=06&sn=HARYANA
# 2020 11
# {'name': 'HIMACHAL PRADESH', 'id': 2}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=02&sn=HIMACHAL%20PRADESH
# 2020 11
# {'name': 'JAMMU AND KASHMIR', 'id': 1}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=01&sn=JAMMU%20AND%20KASHMIR
# 2020 11
# {'name': 'JHARKHAND', 'id': 20}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=20&sn=JHARKHAND
# 2020 11
# {'name': 'KARNATAKA', 'id': 29}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=29&sn=KARNATAKA
# 2020 11
# {'name': 'KERALA', 'id': 32}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=32&sn=KERALA
# 2020 11
# {'name': 'LADAKH', 'id': 37}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=37&sn=LADAKH
# 2020 11
# {'name': 'LAKSHADWEEP', 'id': 31}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=31&sn=LAKSHADWEEP
# 2020 11
# {'name': 'MADHYA PRADESH', 'id': 23}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=23&sn=MADHYA%20PRADESH
# 2020 11
# {'name': 'MAHARASHTRA', 'id': 27}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=27&sn=MAHARASHTRA
# 2020 11
# {'name': 'MANIPUR', 'id': 14}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=14&sn=MANIPUR
# 2020 11
# {'name': 'MEGHALAYA', 'id': 17}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=17&sn=MEGHALAYA
# 2020 11
# {'name': 'MIZORAM', 'id': 15}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=15&sn=MIZORAM
# 2020 11
# {'name': 'NAGALAND', 'id': 13}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=13&sn=NAGALAND
# 2020 11
# {'name': 'ODISHA', 'id': 21}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=21&sn=ODISHA
# 2020 11
# {'name': 'PUNJAB', 'id': 3}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=03&sn=PUNJAB
# 2020 11
# {'name': 'RAJASTHAN', 'id': 8}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=08&sn=RAJASTHAN
# 2020 11
# {'name': 'SIKKIM', 'id': 11}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=11&sn=SIKKIM
# 2020 11
# {'name': 'TAMIL NADU', 'id': 33}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=33&sn=TAMIL%20NADU
# 2020 11
# {'name': 'TELANGANA', 'id': 36}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=36&sn=TELANGANA
# 2020 11
# {'name': 'TRIPURA', 'id': 16}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=16&sn=TRIPURA
# 2020 11
# {'name': 'UTTAR PRADESH', 'id': 5}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=05&sn=UTTAR%20PRADESH
# 2020 11
# {'name': 'UTTARAKHAND', 'id': 9}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=09&sn=UTTARAKHAND
# 2020 11
# {'name': 'WEST BENGAL', 'id': 19}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=11&y=2020&s=19&sn=WEST%20BENGAL
# 2020 12
# {'name': 'ANDAMAN & NICOBAR ISLANDS', 'id': 35}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=35&sn=ANDAMAN%20&%20NICOBAR%20ISLANDS
# 2020 12
# {'name': 'ANDHRA PRADESH', 'id': 28}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=28&sn=ANDHRA%20PRADESH
# 2020 12
# {'name': 'ARUNACHAL PRADESH', 'id': 12}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=12&sn=ARUNACHAL%20PRADESH
# 2020 12
# {'name': 'ASSAM', 'id': 18}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=18&sn=ASSAM
# 2020 12
# {'name': 'BIHAR', 'id': 10}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=10&sn=BIHAR
# 2020 12
# {'name': 'CHHATTISGARH', 'id': 22}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=22&sn=CHHATTISGARH
# 2020 12
# {'name': 'DADRA & NAGAR HAVELI', 'id': 26}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=26&sn=DADRA%20&%20NAGAR%20HAVELI
# 2020 12
# {'name': 'DAMAN & DIU', 'id': 25}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=25&sn=DAMAN%20&%20DIU
# 2020 12
# {'name': 'DELHI', 'id': 7}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=07&sn=DELHI
# 2020 12
# {'name': 'GOA', 'id': 30}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=30&sn=GOA
# 2020 12
# {'name': 'GUJARAT', 'id': 24}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=24&sn=GUJARAT
# 2020 12
# {'name': 'HARYANA', 'id': 6}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=06&sn=HARYANA
# 2020 12
# {'name': 'HIMACHAL PRADESH', 'id': 2}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=02&sn=HIMACHAL%20PRADESH
# 2020 12
# {'name': 'JAMMU AND KASHMIR', 'id': 1}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=01&sn=JAMMU%20AND%20KASHMIR
# 2020 12
# {'name': 'JHARKHAND', 'id': 20}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=20&sn=JHARKHAND
# 2020 12
# {'name': 'KARNATAKA', 'id': 29}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=29&sn=KARNATAKA
# 2020 12
# {'name': 'KERALA', 'id': 32}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=32&sn=KERALA
# 2020 12
# {'name': 'LADAKH', 'id': 37}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=37&sn=LADAKH
# 2020 12
# {'name': 'LAKSHADWEEP', 'id': 31}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=31&sn=LAKSHADWEEP
# 2020 12
# {'name': 'MADHYA PRADESH', 'id': 23}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=23&sn=MADHYA%20PRADESH
# 2020 12
# {'name': 'MAHARASHTRA', 'id': 27}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=27&sn=MAHARASHTRA
# 2020 12
# {'name': 'MANIPUR', 'id': 14}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=14&sn=MANIPUR
# 2020 12
# {'name': 'MEGHALAYA', 'id': 17}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=17&sn=MEGHALAYA
# 2020 12
# {'name': 'MIZORAM', 'id': 15}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=15&sn=MIZORAM
# 2020 12
# {'name': 'NAGALAND', 'id': 13}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=13&sn=NAGALAND
# 2020 12
# {'name': 'ODISHA', 'id': 21}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=21&sn=ODISHA
# 2020 12
# {'name': 'PUNJAB', 'id': 3}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=03&sn=PUNJAB
# 2020 12
# {'name': 'RAJASTHAN', 'id': 8}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=08&sn=RAJASTHAN
# 2020 12
# {'name': 'SIKKIM', 'id': 11}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=11&sn=SIKKIM
# 2020 12
# {'name': 'TAMIL NADU', 'id': 33}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=33&sn=TAMIL%20NADU
# 2020 12
# {'name': 'TELANGANA', 'id': 36}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=36&sn=TELANGANA
# 2020 12
# {'name': 'TRIPURA', 'id': 16}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=16&sn=TRIPURA
# 2020 12
# {'name': 'UTTAR PRADESH', 'id': 5}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=05&sn=UTTAR%20PRADESH
# 2020 12
# {'name': 'UTTARAKHAND', 'id': 9}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=09&sn=UTTARAKHAND
# 2020 12
# {'name': 'WEST BENGAL', 'id': 19}
# https://annavitran.nic.in/unautomatedStDetailMonthDFSOWiseRpt?m=12&y=2020&s=19&sn=WEST%20BENGAL

# %%
master_df = pd.concat(total_data).reset_index(drop=True)
master_df
# Out:
#       month_year  state_code   state_name  \
# 0       Jan-2017          32       KERALA
# 1       Jan-2017          32       KERALA
# 2       Jan-2017          32       KERALA
# 3       Jan-2017          32       KERALA
# 4       Jan-2017          15      MIZORAM
# ...          ...         ...          ...
# 36989   Dec-2020          19  WEST BENGAL
# 36990   Dec-2020          19  WEST BENGAL
# 36991   Dec-2020          19  WEST BENGAL
# 36992   Dec-2020          19  WEST BENGAL
# 36993   Dec-2020          19  WEST BENGAL
#
#                                           dfso  total_rice_allocated  \
# 0                                   DSO KANNUR               4159.63
# 1                               DSO KOZHIKKODE               6441.46
# 2                           DSO PATHANAMTHITTA               2343.70
# 3                                 DSO THRISSUR               6204.74
# 4                                 DCSO LUNGLEI                650.85
# ...                                        ...                   ...
# 36989  Jt. Director of Rationing , Barrackpore               2066.33
# 36990       Jt. Director of Rationing , Hoogly               1340.57
# 36991          Jt. Director of Kolkata - North               1050.83
# 36992                                KALIMPONG                777.41
# 36993                        PASCHIM BARDHAMAN               2131.79
#
#        total_wheat_allocated  total_qty_allocated  \
# 0                    1001.20              5160.83
# 1                    1550.43              7991.89
# 2                     564.12              2907.81
# 3                    1493.45              7698.19
# 4                       0.00               650.85
# ...                      ...                  ...
# 36989                3044.17              5110.50
# 36990                1969.59              3310.16
# 36991                1549.26              2600.09
# 36992                1036.55              1813.95
# 36993                3141.33              5273.12
#
#        total_rice_distributed_unautomated  \
# 0                                 3927.24
# 1                                 6111.81
# 2                                 2154.24
# 3                                 5913.73
# 4                                  650.85
# ...                                   ...
# 36989                                0.00
# 36990                                0.00
# 36991                                0.00
# 36992                                0.00
# 36993                                0.00
#
#        total_wheat_distributed_unautomated  total_qty_distributed_unautomated  \
# 0                                   973.97                            4901.21
# 1                                  1480.11                            7591.92
# 2                                   540.39                            2694.63
# 3                                  1443.37                            7357.10
# 4                                     0.00                             650.85
# ...                                    ...                                ...
# 36989                                 0.00                               0.00
# 36990                                 0.00                               0.00
# 36991                                 0.00                               0.00
# 36992                                 0.00                               0.00
# 36993                                 0.00                               0.00
#
#        percent_qty_distributed_unautomated  total_rice_distributed_automated  \
# 0                                      0.0                              0.00
# 1                                      0.0                              0.00
# 2                                      0.0                              0.00
# 3                                      0.0                              0.00
# 4                                      0.0                              0.00
# ...                                    ...                               ...
# 36989                                  0.0                           1986.90
# 36990                                  0.0                           1307.02
# 36991                                  0.0                           1022.81
# 36992                                  0.0                            840.51
# 36993                                  0.0                           2119.83
#
#        total_wheat_distributed_automated  total_qty_distributed_automated  \
# 0                                   0.00                             0.00
# 1                                   0.00                             0.00
# 2                                   0.00                             0.00
# 3                                   0.00                             0.00
# 4                                   0.00                             0.00
# ...                                  ...                              ...
# 36989                            2924.61                          4911.50
# 36990                            1919.43                          3226.45
# 36991                            1511.89                          2534.70
# 36992                             691.84                          1532.35
# 36993                            3107.35                          5227.18
#
#        percentage_qty_distributed_automated  total_qty_allocated_automated  \
# 0                                       0.0                        4901.21
# 1                                       0.0                        7591.92
# 2                                       0.0                        2694.63
# 3                                       0.0                        7357.10
# 4                                       0.0                         650.85
# ...                                     ...                            ...
# 36989                                   0.0                        4911.50
# 36990                                   0.0                        3226.45
# 36991                                   0.0                        2534.70
# 36992                                   0.0                        1532.35
# 36993                                   0.0                        5227.18
#
#        total_rice_distributed  total_wheat_distributed
# 0                     3927.24                   973.97
# 1                     6111.81                  1480.11
# 2                     2154.24                   540.39
# 3                     5913.73                  1443.37
# 4                      650.85                     0.00
# ...                       ...                      ...
# 36989                 1986.90                  2924.61
# 36990                 1307.02                  1919.43
# 36991                 1022.81                  1511.89
# 36992                  840.51                   691.84
# 36993                 2119.83                  3107.35
#
# [36994 rows x 18 columns]

# %%
filename = f'D:/PDS/pds_dfso_monthly_{date.today().strftime("%d_%m_%Y")}.csv'
filename
# Out:
# 'D:/PDS/pds_dfso_monthly.csv'

# %%
master_df.to_csv(filename, index=False)

# %%
d=0
for t in total_data:
    print(t.shape)
    d = d+t.shape[0]

# %%
d
